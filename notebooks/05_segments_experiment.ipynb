# %% [markdown]
# # Неделя 4 — Эксперимент A/B/C
#
# Задание: `docs/week4_experiment.md`

# %%
import sys
sys.path.append('..')
from src.validation import evaluate, bootstrap_auc_diff

# %% [markdown]
# ## Подход A — единая модель без сегмента/продукта

# %%
# TODO

# %% [markdown]
# ## Подход B — единая модель + сегмент/продукт как признаки

# %%
# TODO

# %% [markdown]
# ## Подход C — отдельная модель на каждый сегмент

# %%
# TODO: не забыть предупреждение, если в сегменте < 100 примеров оттока

# %% [markdown]
# ## Сравнение: общее и по сегментам

# %%
# TODO: таблица AUC/Lift@10% по каждому подходу и сегменту

# %% [markdown]
# ## Bootstrap-проверка значимости различий

# %%
# bootstrap_auc_diff(y_test, score_b, score_c)

# %% [markdown]
# ## Feature importance + SHAP

# %%
# import shap
# explainer = shap.TreeExplainer(model_b)
