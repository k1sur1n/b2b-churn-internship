# %% [markdown]
# # Неделя 3 — Baseline-модели
#
# Задание: `docs/week3_baseline.md`

# %%
import pandas as pd
import sys
sys.path.append('..')
from src.validation import evaluate

# %% [markdown]
# ## 1. Разбиение по времени (out-of-time)

# %%
# train = dataset[dataset['snapshot_date'] <= '2025-04']
# test = dataset[dataset['snapshot_date'] == '2025-07']

# %% [markdown]
# ## 2. Baseline 0 — правило

# %%
# evaluate(y_test, -X_test['rev_last_to_mean'], 'Правило: падение платежа')

# %% [markdown]
# ## 3. Baseline 1 — логистическая регрессия

# %%
# TODO: Pipeline(ColumnTransformer + LogisticRegression), см. гайд раздел 10.1

# %% [markdown]
# ## 4. Сравнение baseline'ов
#
# TODO: таблица метрик правило vs логрегрессия.
